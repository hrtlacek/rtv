# %% [markdown]
# # Real Time Visual Content Creation - Overview and Comparison
# This notebook tries to visualize a dataset containing evaluation of different programmable environments for real time video content creation. Please also refer to https://github.com/hrtlacek/rtv
#
# Some of this data is objective (does a specifix environment run natively on linux or not?) some of it is rather subjective and wishy-washy(is the documentation of language x now 0.8 or 0.7257?). So take it with a grain of salt. Discussion and collaboration via git very welcome.

# %%
# %pylab inline
import pandas as pd
dataset = pd.read_csv("https://github.com/hrtlacek/rtv/raw/master/envCompare.csv")
from mpl_toolkits.mplot3d import Axes3D

dataset
# Out:
# Populating the interactive namespace from numpy and matplotlib
#              name                                address  \
# 0   TouchDesigner             https://www.derivative.ca/
# 1  Max_MSP_Jitter                 https://cycling74.com/
# 2            vvvv                      https://vvvv.org/
# 3      Processing                https://processing.org/
# 4           Unity                   https://unity3d.com/
# 5          Unreal           https://www.unrealengine.com
# 6        KodeLife   https://hexler.net/software/kodelife
# 7  openFrameworks             https://openframeworks.cc/
# 8           smode              http://smode.fr/products/
# 9           notch                 https://www.notch.one/
#
#    learning Curve/Easyness  'Fancy’ Output From The beginning  \
# 0                      0.8                                0.8
# 1                      0.8                                0.7
# 2                      0.7                                0.5
# 3                      0.5                                0.5
# 4                      0.7                                0.7
# 5                      0.7                                0.9
# 6                      0.3                                0.0
# 7                      0.2                                0.0
# 8                      0.8                                0.7
# 9                      0.8                                0.7
#
#    Mostly GPU based  Winowds  MacOS  Linux  Documentation  Open Source  \
# 0                 1        1      1      0            0.8            0
# 1                 0        1      1      0            0.8            0
# 2                 1        1      0      0            0.8            1
# 3                 0        1      1      1            0.7            1
# 4                 1        1      1      1            0.7            0
# 5                 1        1      1      1            0.7            0
# 6                 1        1      1      1            0.0            0
# 7                 1        1      1      1            0.7            1
# 8                 1        1      1      0            0.8            0
# 9                 1        1      0      0            0.8            0
#
#                          ...                          Web  Procedural Geo  \
# 0                        ...                          0.0             0.9
# 1                        ...                          0.0             0.7
# 2                        ...                          0.0             0.8
# 3                        ...                          0.8             0.7
# 4                        ...                          0.8             0.3
# 5                        ...                          0.8             0.3
# 6                        ...                          0.0             0.4
# 7                        ...                          0.0             0.5
# 8                        ...                          0.0             0.8
# 9                        ...                          0.0             0.9
#
#    2D postPro  Audio Analysis  Computer Vision/Analysis  DMX/Artnet Support  \
# 0         1.0             0.8                       0.2                 1.0
# 1         0.6             1.0                       0.7                 0.5
# 2         0.8             0.8                       0.8                 1.0
# 3         0.7             0.8                       0.8                 0.5
# 4         0.5             0.7                       0.0                 0.3
# 5         0.5             0.7                       0.0                 0.2
# 6         0.5             0.5                       0.0                 0.0
# 7         0.5             0.8                       0.9                 0.5
# 8         1.0             0.5                       0.5                 1.0
# 9         1.0             0.5                       0.5                 1.0
#
#         Avg           Cost  Scripting/Additional Language(s)  \
# 0  0.298148          Free*                   Python/C++/GLSL
# 1  0.285185        $399.00                  C++/js/java/GLSL
# 2  0.255556          Free*                           C#/GLSL
# 3  0.177778           Free                              Java
# 4  0.248148          Free*                           C#/GLSL
# 5  0.282099          Free*                       C++/js/GLSL
# 6  0.344444           Free                              GLSL
# 7  0.300000           Free                               C++
# 8  0.318519          Free*                               NaN
# 9  0.359877  £99 perpetual                               NaN
#
#                                   Reference Tutorial
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3       https://www.openprocessing.org/sketch/425701
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7        https://www.youtube.com/watch?v=IiTsE7P-GDs
# 8  https://www.youtube.com/watch?time_continue=35...
# 9                http://www.notch.one/learn/academy/
#
# [10 rows x 24 columns]

# %%
transposed = dataset.T.loc['learning Curve/Easyness':'DMX/Artnet Support']
transposed.columns = dataset['name']
transposed
# Out:
# name                                               TouchDesigner  \
# learning Curve/Easyness                                      0.8
# 'Fancy’ Output From The beginning                            0.8
# Mostly GPU based                                               1
# Winowds                                                        1
# MacOS                                                          1
# Linux                                                          0
# Documentation                                                0.8
# Open Source                                                    0
# Science (strong Emphasis on openness, reproduce...           0.7
# Creativity(strong emphasis on expression)                      1
# Experimental (strong Emphasis on openness, enco...           0.9
# Show Production (stable + feature-rich well sui...             1
# Web                                                            0
# Procedural Geo                                               0.9
# 2D postPro                                                     1
# Audio Analysis                                               0.8
# Computer Vision/Analysis                                     0.2
# DMX/Artnet Support                                             1
#
# name                                               Max_MSP_Jitter vvvv  \
# learning Curve/Easyness                                       0.8  0.7
# 'Fancy’ Output From The beginning                             0.7  0.5
# Mostly GPU based                                                0    1
# Winowds                                                         1    1
# MacOS                                                           1    0
# Linux                                                           0    0
# Documentation                                                 0.8  0.8
# Open Source                                                     0    1
# Science (strong Emphasis on openness, reproduce...            0.7  0.7
# Creativity(strong emphasis on expression)                     0.9  0.9
# Experimental (strong Emphasis on openness, enco...            0.9    1
# Show Production (stable + feature-rich well sui...            0.7  0.8
# Web                                                             0    0
# Procedural Geo                                                0.7  0.8
# 2D postPro                                                    0.6  0.8
# Audio Analysis                                                  1  0.8
# Computer Vision/Analysis                                      0.7  0.8
# DMX/Artnet Support                                            0.5    1
#
# name                                               Processing Unity Unreal  \
# learning Curve/Easyness                                   0.5   0.7    0.7
# 'Fancy’ Output From The beginning                         0.5   0.7    0.9
# Mostly GPU based                                            0     1      1
# Winowds                                                     1     1      1
# MacOS                                                       1     1      1
# Linux                                                       1     1      1
# Documentation                                             0.7   0.7    0.7
# Open Source                                                 1     0      0
# Science (strong Emphasis on openness, reproduce...        0.8   0.8    0.3
# Creativity(strong emphasis on expression)                 0.6   0.7    0.7
# Experimental (strong Emphasis on openness, enco...        0.9   0.8    0.7
# Show Production (stable + feature-rich well sui...        0.7   0.5    0.4
# Web                                                       0.8   0.8    0.8
# Procedural Geo                                            0.7   0.3    0.3
# 2D postPro                                                0.7   0.5    0.5
# Audio Analysis                                            0.8   0.7    0.7
# Computer Vision/Analysis                                  0.8     0      0
# DMX/Artnet Support                                        0.5   0.3    0.2
#
# name                                               KodeLife openFrameworks  \
# learning Curve/Easyness                                 0.3            0.2
# 'Fancy’ Output From The beginning                         0              0
# Mostly GPU based                                          1              1
# Winowds                                                   1              1
# MacOS                                                     1              1
# Linux                                                     1              1
# Documentation                                             0            0.7
# Open Source                                               0              1
# Science (strong Emphasis on openness, reproduce...      0.2            0.9
# Creativity(strong emphasis on expression)               0.7            0.6
# Experimental (strong Emphasis on openness, enco...      0.9            0.9
# Show Production (stable + feature-rich well sui...      0.5            0.5
# Web                                                       0              0
# Procedural Geo                                          0.4            0.5
# 2D postPro                                              0.5            0.5
# Audio Analysis                                          0.5            0.8
# Computer Vision/Analysis                                  0            0.9
# DMX/Artnet Support                                        0            0.5
#
# name                                               smode notch
# learning Curve/Easyness                              0.8   0.8
# 'Fancy’ Output From The beginning                    0.7   0.7
# Mostly GPU based                                       1     1
# Winowds                                                1     1
# MacOS                                                  1     0
# Linux                                                  0     0
# Documentation                                        0.8   0.8
# Open Source                                            0     0
# Science (strong Emphasis on openness, reproduce...     0     0
# Creativity(strong emphasis on expression)              1     1
# Experimental (strong Emphasis on openness, enco...   0.7   0.7
# Show Production (stable + feature-rich well sui...   0.8     1
# Web                                                    0     0
# Procedural Geo                                       0.8   0.9
# 2D postPro                                             1     1
# Audio Analysis                                       0.5   0.5
# Computer Vision/Analysis                             0.5   0.5
# DMX/Artnet Support                                     1     1

# %%
p = transposed.plot(figsize=[17,15],subplots=True, kind='bar')
plt.xticks=transposed.index
show()

# %% [markdown]
# # 3d feature comparison
# Below you can compare the environments in a 3d plot. You can choose which 3 features you want to compare via the numbers in third to fith line. You can just count the features from above (0 based!) and enter the number below. For example if you want to use if a software runs on macOS  for the x-axis you would set the line
#
# ```xfeat = list(transposed.index)[8]```
#
# to
#
#
# ```xfeat = list(transposed.index)[5]```
#
# After you have done that you need to execute the cell via ctrl-enter (or the little play button to the top left of the cell)

# %%
fig = plt.figure(figsize=[10,10])

xfeat = list(transposed.index)[8] #change these numbers to plot oter features in 3d!
yfeat = list(transposed.index)[9]
zfeat = list(transposed.index)[11]

xs = dataset[xfeat]
ys = dataset[yfeat]
zs = dataset[zfeat]



ax = fig.gca(projection='3d')


ax.set_xlabel(xfeat)
ax.set_ylabel(yfeat)
ax.set_zlabel(zfeat)

for i in range(len(xs)):
  
  text = list(transposed.columns)[i]
  ax.text(xs[i], ys[i], zs[i], text)

for i in range(len(xs)):
    color = p[i].get_children()[0].get_facecolor()
    ax.plot([0,xs[i]], [ys[i], ys[i]], [zs[i], zs[i]], color=color)
    ax.plot([xs[i],xs[i]], [1, ys[i]], [zs[i], zs[i]], color=color)
    ax.plot([xs[i],xs[i]], [ys[i], ys[i]], [0, zs[i]], color=color)
  
  
ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_zlim(0,1)
ax.scatter(xs,ys,zs)
show()

# %% [markdown]
# # Comparison by Feature

# %%
tt = transposed.T
tt.plot(kind='bar', subplots=True, figsize=[17,25])
plt.xticks=list(dataset['name'])
plt.ylim([0,1])
show()

# %% [markdown]
# # Sorted Feature Plot

# %%
for i in range(len(transposed.index)):
    feat = transposed.index[i]

    vals = tt[feat]

    vals.sort_values().plot(kind='bar')
    plt.title(feat)
    plt.grid()
    show()
